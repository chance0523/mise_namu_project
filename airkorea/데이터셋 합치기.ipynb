# %%
import pandas as pd

# %% [markdown]
# ### 미세먼지 데이터

# %%
df_dust_1 = pd.read_csv('mise_mean_data.csv', encoding='utf-8-sig')
df_dust_1 = df_dust_1.loc[ :, ["시군구명", "4월~12월"]]

# 시군구명 오름차순 정렬
df_dust_1.sort_values(by=["시군구명"], ascending=[True], inplace=True)
df_dust_1
# Out:
#     시군구명     4월~12월
# 37   강남구  31.384878
# 5    강남구  43.434215
# 11   강동구  39.346679
# 12   강동구  40.053874
# 35   강북구  30.993843
# 2    강서구  44.349798
# 29   강서구  34.657792
# 13   관악구  41.067829
# 26   광진구  36.165750
# 14   구로구  38.052528
# 28   금천구  35.394203
# 39   금천구  48.493463
# 16   노원구  39.470401
# 27   노원구  35.028727
# 23   도봉구  36.083651
# 9   동대문구  42.631789
# 32  동대문구  30.964280
# 4    동작구  44.330294
# 25   동작구  36.227383
# 15   마포구  39.825172
# 1    마포구  44.712763
# 21  서대문구  36.181771
# 8    서초구  41.482441
# 18   서초구  37.500697
# 19   성동구  37.907307
# 10   성동구  41.584158
# 22   성북구  37.701265
# 7    성북구  41.569886
# 17   송파구  38.610793
# 30   양천구  33.920038
# 6   영등포구  43.682409
# 3   영등포구  42.860356
# 36   용산구  30.001323
# 0    용산구  47.427438
# 24   은평구  36.578257
# 33   종로구  32.669498
# 34   종로구  32.148579
# 20    중구  39.762024
# 31    중구  33.235991
# 38   중랑구  29.647813

# %%
# 구별로 데이터 합치기
df_dust_group = df_dust_1["4월~12월"].groupby(df_dust_1["시군구명"])

# %%
df_dust = pd.DataFrame(df_dust_group.mean())
df_dust
# Out:
#          4월~12월
# 시군구명
# 강남구   37.409547
# 강동구   39.700276
# 강북구   30.993843
# 강서구   39.503795
# 관악구   41.067829
# 광진구   36.165750
# 구로구   38.052528
# 금천구   41.943833
# 노원구   37.249564
# 도봉구   36.083651
# 동대문구  36.798035
# 동작구   40.278838
# 마포구   42.268968
# 서대문구  36.181771
# 서초구   39.491569
# 성동구   39.745733
# 성북구   39.635576
# 송파구   38.610793
# 양천구   33.920038
# 영등포구  43.271382
# 용산구   38.714380
# 은평구   36.578257
# 종로구   32.409038
# 중구    36.499007
# 중랑구   29.647813

# %% [markdown]
# ### 생활인구 데이터

# %%
# living_population (생활인구) 파일 불러오기
df_population = pd.read_csv('living_population.csv', encoding='utf-8-sig')
df_population = df_population.loc[ 1: ,["시군구명", "연 평균"]]
df_population.sort_values(by=["시군구명"], ascending=['True'], inplace=True)
df_population
# Out:
#     시군구명          연 평균
# 23   강남구  1.270695e+08
# 25   강동구  7.344847e+07
# 9    강북구  4.648532e+07
# 16   강서구  8.412628e+07
# 21   관악구  7.818201e+07
# 5    광진구  6.186909e+07
# 17   구로구  6.447410e+07
# 18   금천구  3.617366e+07
# 11   노원구  7.932390e+07
# 10   도봉구  4.454764e+07
# 6   동대문구  6.015084e+07
# 20   동작구  6.380677e+07
# 14   마포구  7.619192e+07
# 13  서대문구  6.175380e+07
# 22   서초구  9.367481e+07
# 4    성동구  5.447534e+07
# 8    성북구  6.830498e+07
# 24   송파구  1.147290e+08
# 15   양천구  6.027714e+07
# 19  영등포구  7.893340e+07
# 3    용산구  4.887740e+07
# 12   은평구  6.763026e+07
# 1    종로구  5.350901e+07
# 2     중구  5.578370e+07
# 7    중랑구  5.492773e+07

# %% [markdown]
# ### 교통량 데이터

# %%
df_traffic_1 = pd.read_csv('서울시_교통량_경기도제외.csv', encoding='utf-8-sig')
df_traffic_1 = df_traffic_1.loc[ :, ["시군구명", "합계"]]

# %%
# 시군구명 오름차순 정렬
df_traffic_1.sort_values(by=["시군구명"], ascending=[True], inplace=True)
df_traffic_1
# Out:
#     시군구명      합계
# 62   강남구  210198
# 32   강남구   46886
# 66   강남구  129932
# 109  강남구  100965
# 110  강남구   64100
# 108  강남구   64513
# 112  강남구   75537
# 113  강남구   76324
# 122  강남구  139487
# 111  강남구   64306
# 70   강동구   16934
# 29   강동구  199281
# 28   강동구   82115
# 88   강서구   73750
# 43   강서구   26125
# 47   강서구  170904
# 90   강서구   39923
# 51   강서구  106390
# 91   강서구   55298
# 102  관악구   18411
# 103  관악구  101960
# 65   광진구  132724
# 77   광진구   69925
# 25   광진구   31681
# 37   구로구   12055
# 46   구로구   48451
# 39   구로구   28324
# 38   구로구   30394
# 98   구로구   94691
# 92   구로구   50370
# ..   ...     ...
# 59   용산구   64761
# 58   용산구   96648
# 22   용산구   15582
# 48   은평구   37883
# 84   은평구   72467
# 49   은평구   44692
# 13   종로구   49446
# 1    종로구   78237
# 71   종로구   46704
# 72   종로구   45746
# 2    종로구   33792
# 4    종로구   59958
# 6    종로구   39126
# 7    종로구   53223
# 5    종로구   42976
# 14   종로구   46469
# 17    중구   35238
# 12    중구   62856
# 16    중구   79221
# 20    중구   27261
# ...

# %%
# 구별로 데이터 합치기
df_traffic_group = df_traffic_1["합계"].groupby(df_traffic_1["시군구명"])

# %%
df_traffic = pd.DataFrame(df_traffic_group.sum())
df_traffic
# Out:
#            합계
# 시군구명
# 강남구    972248
# 강동구    298330
# 강서구    472390
# 관악구    120371
# 광진구    234330
# 구로구    318401
# 금천구    390588
# 노원구    278778
# 도봉구    103482
# 동작구    327946
# 마포구    698561
# 서대문구   257333
# 서초구   1084842
# 성동구    372062
# 성북구    396402
# 송파구    545075
# 양천구    322022
# 영등포구   639478
# 용산구    635953
# 은평구    155042
# 종로구    495677
# 중구     563769
# 중랑구    270354

# %% [markdown]
# ### 난방

# %%
df_gas = pd.read_csv('서울시_구별_난방.csv', encoding='utf-8-sig')
df_gas = df_gas.loc[ : ]

# 시군구명 오름차순 정렬
df_gas.sort_values(by=["시군구명"], ascending=[True], inplace=True)
df_gas
# Out:
#     시군구명      합계
# 22   강남구  237164
# 24   강동구  168770
# 8    강북구  146499
# 15   강서구  258794
# 20   관악구  275217
# 4    광진구  177923
# 16   구로구  191043
# 17   금천구  120888
# 10   노원구  205049
# 9    도봉구  139386
# 5   동대문구  180219
# 19   동작구  191220
# 13   마포구  195075
# 12  서대문구  151245
# 21   서초구  187278
# 3    성동구  141875
# 7    성북구  193616
# 23   송파구  267365
# 14   양천구  179681
# 18  영등포구  196484
# 2    용산구  117690
# 11   은평구  205219
# 0    종로구   83550
# 1     중구   70798
# 6    중랑구  181187

# %% [markdown]
# ### 전력

# %%
df_elec = pd.read_csv('서울시_구별_전력.csv', encoding='utf-8-sig')
df_elec = df_elec.loc[ : ]

# 시군구명 오름차순 정렬
df_elec.sort_values(by=["시군구명"], ascending=[True], inplace=True)
df_elec
# Out:
#     시군구명       합계
# 22   강남구  4668552
# 24   강동구  1534686
# 8    강북구   944660
# 15   강서구  2517803
# 20   관악구  1744043
# 4    광진구  1684592
# 16   구로구  1903682
# 17   금천구  1639417
# 10   노원구  1538956
# 9    도봉구   912362
# 5   동대문구  1469529
# 19   동작구  1303621
# 13   마포구  2147213
# 12  서대문구  1268429
# 21   서초구  3340952
# 3    성동구  2203585
# 7    성북구  1473874
# 23   송파구  2820372
# 14   양천구  1698490
# 18  영등포구  2690642
# 2    용산구  1448285
# 11   은평구  1424502
# 0    종로구  1779509
# 1     중구  2516717
# 6    중랑구  1135735

# %% [markdown]
# ### 경유차 데이터

# %%
df_car = pd.read_csv('구별_차량등록_현황.csv', encoding='utf-8-sig')
df_car = df_car.loc[ : ]

# 시군구명 오름차순 정렬
df_car.sort_values(by=["시군구명"], ascending=[True], inplace=True)
df_car
# Out:
#     시군구명     합계
# 2    강남구  72783
# 8    강동구  49164
# 21   강북구  29319
# 1    강서구  73519
# 11   관악구  44110
# 16   광진구  38445
# 5    구로구  57190
# 17   금천구  37572
# 7    노원구  52925
# 19   도봉구  35425
# 15  동대문구  38595
# 18   동작구  36751
# 13   마포구  42667
# 20  서대문구  31153
# 3    서초구  61467
# 14   성동구  40275
# 12   성북구  43227
# 0    송파구  85648
# 6    양천구  53192
# 4   영등포구  57571
# 22   용산구  26953
# 9    은평구  46574
# 24   종로구  19127
# 23    중구  22016
# 10   중랑구  44864

# %% [markdown]
# ### 공사현황

# %%
df_con = pd.read_csv('서울시_공사현황.csv', encoding='utf-8-sig')
df_con = df_con.loc[ : ]

# 시군구명 오름차순 정렬
df_con.sort_values(by=["시군구명"], ascending=[True], inplace=True)
df_con
# Out:
#     시군구명   합계
# 22   강남구  169
# 24   강동구  167
# 8    강북구  113
# 15   강서구  183
# 20   관악구  116
# 4    광진구   89
# 16   구로구  116
# 17   금천구  108
# 10   노원구  176
# 9    도봉구  119
# 5   동대문구  129
# 19   동작구  113
# 13   마포구  186
# 12  서대문구  122
# 21   서초구  118
# 3    성동구  228
# 7    성북구  118
# 23   송파구  184
# 14   양천구  134
# 18  영등포구  129
# 2    용산구   81
# 11   은평구  104
# 0    종로구  163
# 1     중구  163
# 6    중랑구   99

# %% [markdown]
# ### 도로굴착

# %%
df_road = pd.read_csv('서울시_도로굴착.csv', encoding='utf-8-sig')
df_road = df_road.loc[ : ]

# 시군구명 오름차순 정렬
df_road.sort_values(by=["시군구명"], ascending=[True], inplace=True)
df_road
# Out:
#     시군구명   합계
# 2    강남구  258
# 8    강동구  747
# 21   강북구  103
# 1    강서구  468
# 11   관악구  112
# 16   광진구  193
# 5    구로구  106
# 17   금천구  129
# 7    노원구  155
# 19   도봉구   84
# 15  동대문구   90
# 18   동작구  160
# 13   마포구   95
# 20  서대문구   87
# 3    서초구  296
# 14   성동구   43
# 12   성북구  352
# 0    송파구  155
# 6    양천구  218
# 4   영등포구  124
# 22   용산구  213
# 9    은평구  101
# 24   종로구  255
# 23    중구  150
# 10   중랑구  164

# %% [markdown]
# ### 데이터셋 합쳐서 데이터프레임 만들기

# %%
# 구 이름 리스트로 만들기
name_list = list(df_road["시군구명"])
name_list
# Out:
# ['강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서대문구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '중구',
#  '중랑구']

# %%
# 데이터프레임 생성
df = pd.DataFrame(index = name_list)

# %%
# 데이터프레임 merge
df = pd.merge(df_dust, df_traffic, on="시군구명", how="inner")
# df = pd.merge(df, df_traffic, on="시군구명", how="inner")
df = pd.merge(df, df_gas, on="시군구명", how="inner")
# df = pd.merge(df, df_elec, on="시군구명", how="inner")
df = pd.merge(df, df_car, on="시군구명", how="inner")
# df = pd.merge(df, df_con, on="시군구명", how="inner")
# df = pd.merge(df, df_road, on="시군구명", how="inner")

# df.columns = ["시군구명", "미세먼지", "생활인구", "교통량", "난방", "전력", "경유차", "건설현장", "도로굴착"]
df.columns = ["시군구명", "미세먼지", "교통량", "난방", "경유차"]

df
# Out:
#     시군구명       미세먼지      교통량      난방    경유차
# 0    강남구  37.409547   972248  237164  72783
# 1    강동구  39.700276   298330  168770  49164
# 2    강서구  39.503795   472390  258794  73519
# 3    관악구  41.067829   120371  275217  44110
# 4    광진구  36.165750   234330  177923  38445
# 5    구로구  38.052528   318401  191043  57190
# 6    금천구  41.943833   390588  120888  37572
# 7    노원구  37.249564   278778  205049  52925
# 8    도봉구  36.083651   103482  139386  35425
# 9    동작구  40.278838   327946  191220  36751
# 10   마포구  42.268968   698561  195075  42667
# 11  서대문구  36.181771   257333  151245  31153
# 12   서초구  39.491569  1084842  187278  61467
# 13   성동구  39.745733   372062  141875  40275
# 14   성북구  39.635576   396402  193616  43227
# 15   송파구  38.610793   545075  267365  85648
# 16   양천구  33.920038   322022  179681  53192
# 17  영등포구  43.271382   639478  196484  57571
# 18   용산구  38.714380   635953  117690  26953
# 19   은평구  36.578257   155042  205219  46574
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams

# %%
plt.rc('font', family='Malgun Gothic')

# %%
plt.style.use(['ggplot'])

# %%
df.to_csv("데이터프레임 완성.csv", encoding="utf-8-sig")

# %%
from sklearn import preprocessing
col = ['미세먼지','교통량','난방','경유차']
x = df[col].values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x.astype(float))
df_norm = pd.DataFrame(x_scaled, columns=col, index = df['시군구명'])
import numpy as np
df_norm['평균'] = np.mean(df_norm[col[1:]],axis=1)
df_norm

# %%
# col = ['미세먼지','생활인구','교통량','난방','전력','경유차','건설현장']
col = ['미세먼지','교통량','난방','경유차']

# %%
x = df[col].values

# %%
min_max_scaler = preprocessing.MinMaxScaler()

# %%
x_scaled = min_max_scaler.fit_transform(x.astype(float))

# %%
df_norm = pd.DataFrame(x_scaled, columns=col, index = df['시군구명'])

# %%
import numpy as np
df_norm['평균'] = np.mean(df_norm[col[1:]],axis=1)

# %%
df_norm
# Out:
#           미세먼지       교통량        난방       경유차        평균
# 시군구명
# 강남구   0.569728  0.885267  0.813848  0.806602  0.835239
# 강동구   0.737873  0.198549  0.479271  0.451542  0.376454
# 강서구   0.723451  0.375915  0.919660  0.817667  0.704414
# 관악구   0.838254  0.017210  1.000000  0.375566  0.464258
# 광진구   0.478431  0.133333  0.524046  0.290405  0.315928
# 구로구   0.616925  0.219001  0.588228  0.572195  0.459808
# 금천구   0.902555  0.292559  0.245036  0.277281  0.271625
# 노원구   0.557985  0.178626  0.656744  0.508080  0.447817
# 도봉구   0.472405  0.000000  0.335527  0.245005  0.193511
# 동작구   0.780341  0.228727  0.589094  0.264939  0.360920
# 마포구   0.926421  0.606382  0.607952  0.353873  0.522736
# 서대문구  0.479607  0.156773  0.393540  0.180785  0.243699
# 서초구   0.722553  1.000000  0.569810  0.636491  0.735434
# 성동구   0.741210  0.273681  0.347703  0.317915  0.313100
# 성북구   0.733124  0.298484  0.600815  0.362292  0.420530
# 송파구   0.657903  0.449981  0.961589  1.000000  0.803856
# ...

# %%
# target_col = ['미세먼지','생활인구','교통량','난방','전력','경유차','건설현장','평균']
target_col = ['미세먼지','교통량','난방','경유차','평균']

# %%
df_norm_sort = df_norm.sort_values(by='평균',ascending=False)

# %%
plt.figure(figsize = (50,50))
plt.rc('font',size=30)
sns.heatmap(df_norm_sort[target_col], annot=True, fmt='f', linewidths=.5, cmap='YlGnBu')
# plt.title()
plt.show()
