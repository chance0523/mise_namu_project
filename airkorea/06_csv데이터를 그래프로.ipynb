# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import rcParams
import numpy as np
import os

# %%
plt.rc('font', family='Malgun Gothic')

# %%
# Out:
# Dobong_Sirubong
# Dongdaemoon_Cheonhodaero
# Dongdaemoon_Hongreungro
# Dongjak_Dongjakdaero
# Enpyeong_JinHeungro
# Gangdong_Cheonhodaero
# Gangdong_Gucheonmeonro
# Gangnam_Dosandaero
# Gangnam_Hakdongro
# Gangseo_Gangseoro
# Gangseo_Magokdong
# Geumcheon_Doksandong
# Geumcheon_Geumharo
# Guro_Gamasanro
# Gwanak_Sinrim
# Gwangjin_Gwangnaruro
# Jongno_Jongno
# Jongro_Jonro35gagil
# Jungnang_Yongmasanro
# Jung_Cheonggaecheonro
# Jung_Deoksugunggil
# Mapo_Nogosandong
# Mapo_Poeunro
# Nowon_Hwarang
# Nowon_Sangyero
# Seocho_Gangnamdaero
# Seocho_Sinbanporo
# Seodaemoon_Segeomjeongro
# Seongbuk_Donamdong
# Seongbuk_Samyang
# Seongbuk_Samyangro
# Seongdong_Ddukseomro
# Seongdong_Ganbyeonbukro
# Songpagu_Baekjegobunro
# Yangcheon_Chungang
# Yeongdengpo_Dangsan
# Yeongdeungpo_Yeongjungro
# Yongsan_Hangandaero
# Yongsan_Hannamdaero

# %%
def read_csv(station_name):
    yearList = ['2016','2017','2018','2019','2020']
    for year in yearList: 
        if year != '2020':
            for month in range(1,13):
                df1 = pd.read_csv(f'station_list/{station_name}/{year}/{station_name}_{year}_{month}.csv')
        else:
            df1 = pd.read_csv(f'station_list/{station_name}/{year}/{station_name}_2020_1.csv')

# %%
def read_csv_only_one(station_name, year, month):
    if year != '2020':
        df1 = pd.read_csv(f'station_list/{station_name}/{year}/{station_name}_{year}_{month}.csv')
    else:
        df1 = pd.read_csv(f'station_list/{station_name}/{year}/{station_name}_2020_1.csv')
    return df1

# %%
# read_csv('Gangnam_Hakdongro')
df1 = read_csv_only_one('Gangnam_Hakdongro','2019','5')
df2 = read_csv_only_one('Gangnam_Dosandaero','2019','5')
df3 = read_csv_only_one('Gangdong_Gucheonmeonro','2019','5')

# %%
x=[_ for _ in range(744)]
time=[]
for i in df1['time']:
    time.append(i)
time_ticks=[]
for i in range(len(time)):
    if i%24 == 0:
        time_ticks.append(i)
ticks_convert=[]
for i in range(len(time)):
#     i = str(i+1) + '일'
    ticks_convert.append(i+1)
h_pm10=[]
h_pm2_5=[]
for i in df1['pm10']:
    h_pm10.append(i)
for i in df1['pm2.5']:
    h_pm2_5.append(i)

# %%
d_pm10=[]
d_pm2_5=[]
for i in df2['pm10']:
    d_pm10.append(i)
for i in df2['pm2.5']:
    d_pm2_5.append(i)

# %%
g_pm10=[]
g_pm2_5=[]
for i in df3['pm10']:
    g_pm10.append(i)
for i in df3['pm2.5']:
    g_pm2_5.append(i)

# %%
dnp_pm10 = np.array(d_pm10)
hnp_pm10 = np.array(h_pm10)
cha = dnp_pm10 - hnp_pm10

# %%
plt.figure(figsize=(12, 5))
# plt.plot(x, h_pm10, label='h_pm10')
# plt.plot(x, h_pm2_5, label='h_pm2.5')

# plt.plot(x, d_pm10, label='d_pm10')
# plt.plot(x, d_pm2_5, label='d_pm2.5')

# plt.plot(x, g_pm10, label='g_pm10')
plt.plot(x, cha)
plt.legend()
plt.xticks(time_ticks,ticks_convert)
plt.xlabel('일')
plt.ylabel('미세먼지 농도')
plt.show()
# Out:
# No handles with labels found to put in legend.
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 51068 missing from current font.
#   font.load_char(ord(s), flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 48120 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47676 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 45453 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 48120 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47676 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 45453 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)
